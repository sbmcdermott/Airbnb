# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
results = pd.read_csv('data_for_viz/weekends.csv')
results.drop(columns = ['Unnamed: 0'], axis=1, inplace=True)
results.head()
# Out:
#                                            name  \
# 0   NC5 The Joint!!  Downtown Nashville Studio!
# 1  Brand-New Condo, 2 Blocks to Centennial Park
# 2         DOWNTOWN NASHVILLE - COMFY & COZY (C)
# 3                                    Tiny haven
# 4    1 BR Apartment!! Just 2 miles to Downtown!
#
#                         category  superhost  \
# 0  Entire apartment in Nashville        NaN
# 1  Entire apartment in Nashville        NaN
# 2  Entire apartment in Nashville  SUPERHOST
# 3  Entire apartment in Nashville  SUPERHOST
# 4  Entire apartment in Nashville        NaN
#
#                                                  url  avg_stars  review_count  \
# 0  /rooms/46779266?check_in=2020-12-17&check_out=...        NaN           NaN
# 1  /rooms/35440277?check_in=2020-12-17&check_out=...       4.64          14.0
# 2  /rooms/29543248?check_in=2020-12-17&check_out=...       4.93          76.0
# 3  /rooms/20137844?check_in=2020-12-17&check_out=...       4.93         193.0
# 4  /rooms/44064578?check_in=2020-12-17&check_out=...       4.00          10.0
#
#    guests beds     bedroom    bath     checkin    checkout previous_price  \
# 0       6    2      Studio  1 bath  2020-12-17  2020-12-20            NaN
# 1       4    2   1 bedroom  1 bath  2020-12-17  2020-12-20            122
# 2       6    2  2 bedrooms  1 bath  2020-12-17  2020-12-20            NaN
# 3       4    4  2 bedrooms  1 bath  2020-12-17  2020-12-20            NaN
# 4       4    1   1 bedroom  1 bath  2020-12-17  2020-12-20             87
#
#   discounted not_discounted  current_nightly  total cost  room_fee  \
# 0        NaN             55               55         245       165
# 1         58            NaN               58         329       174
# 2        NaN             63               63         302       189
# 3        NaN             54               54         259       162
# 4         62            NaN               62         257       186
#
#    taxes_fees_cleaning
# 0                   80
# 1                  155
# 2                  113
# 3                   97
# 4                   71

# %%
# Creating dataset 
a = results['guests']

# Creating histogram 
fig, ax = plt.subplots(figsize =(10, 7)) 
ax.hist(a , bins='auto', color='#0504aa', alpha=0.7, rwidth=0.85) 
plt.title('Listings Per Number of Guests')  

# Show plot 
plt.show()

# %%
plt.style.use('seaborn-whitegrid')
x = results['guests']
y = results['total cost']

plt.xlabel('Number of Guests')
plt.ylabel('Total Cost')

plt.plot(x, y, 'o', color='blue', alpha=0.1);

# %%
checkin_grouped = results.groupby('checkin')
grouped_mean = checkin_grouped.mean()
grouped_mean.reset_index(inplace=True)
grouped_mean.head()
# Out:
#       checkin  avg_stars  review_count    guests  current_nightly  \
# 0  2020-12-17   4.832845     59.506158  6.798571       240.479524
# 1  2020-12-24   4.816610     58.652397  7.118421       344.406080
# 2  2020-12-31   4.827160     62.864684  6.162146       347.323689
# 3  2021-01-07   4.836105     70.260259  6.350135       242.370237
# 4  2021-01-14   4.822290     70.441355  5.838907       226.664763
#
#     total cost     room_fee  taxes_fees_cleaning
# 0   963.807143   721.438571           242.368571
# 1  1332.772232  1033.218240           299.553993
# 2  1307.571429  1041.971067           265.600362
# 3   957.131713   727.110711           230.021002
# 4   890.269576   679.994290           210.275285

# %%
plt.plot(grouped_mean['checkin'], grouped_mean['total cost'], color='blue', marker='o')
plt.title('Average Price Per Check In Date', fontsize=14)
plt.xlabel('Check In Date', fontsize=14)
plt.ylabel('Average Price Per Listing', fontsize=14)
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %%
plt.style.use('seaborn-whitegrid')
x = results['avg_stars']
y = results['review_count']

plt.xlabel('Star Rating')
plt.ylabel('Number of Reviews')

plt.plot(x, y, 'o', color='blue', alpha=0.1);

# %%
guests_grouped = results.groupby('guests')
guests_mean = guests_grouped.mean()
guests_mean.reset_index(inplace=True)
guests_mean.head(20)
# Out:
#     guests  avg_stars  review_count  current_nightly   total cost  \
# 0        1   4.762962    124.307065       106.677198   381.817308
# 1        2   4.845836     91.482071       125.039628   465.903519
# 2        3   4.809955    117.064914       124.791245   482.277496
# 3        4   4.819518     82.864102       177.920518   685.516507
# 4        5   4.821450     86.459786       180.108402   701.141924
# 5        6   4.781201     60.163769       245.031018   949.850489
# 6        7   4.819966     74.573348       268.468687  1055.181818
# 7        8   4.829058     48.803140       333.315410  1308.016643
# 8        9   4.846996     70.151210       308.175824  1215.382784
# 9       10   4.817022     45.612718       434.455148  1666.957726
# 10      11   4.864828     97.206897       480.510417  1857.895833
# 11      12   4.876816     44.847754       671.678635  2545.626652
# 12      14   4.784167     29.000000       512.328571  2027.757143
# 13      15        NaN           NaN       574.136364  2185.545455
# 14      16   4.896748     21.591565      1152.954978  4354.533291
#
#        room_fee  taxes_fees_cleaning
# 0    320.031593            61.785714
# 1    375.118884            90.784635
# 2    374.373734           107.903763
# 3    533.761555           151.754952
# 4    540.325207           160.816717
# 5    735.093053           214.757436
# 6    805.406061           249.775758
# 7    999.946231           308.070411
# 8    924.527473           290.855311
# 9   1303.365444           363.592282
# 10  1441.531250           416.364583
# 11  2015.035906           530.590747
# 12  1536.985714           490.771429
# 13  1722.409091           463.136364
# 14  3458.864933           895.668358

# %%
# Creating bar chart
plt.bar(guests_mean['guests'], guests_mean['review_count'])
plt.title('Reviews per Guest Count')  

# Show plot 
plt.show()

# %%
# Creating bar chart
plt.bar(guests_mean['guests'], guests_mean['total cost'])
plt.title('Total Cost v Guests')  

# Show plot 
plt.show()

# %%
# Creating bar chart
plt.bar(guests_mean['guests'], guests_mean['room_fee'])
plt.title('Total Room Fee v Guests')  

# Show plot 
plt.show()

# %%
# Creating bar chart
plt.bar(guests_mean['guests'], guests_mean['current_nightly'])
plt.title('Nightly Rate v Guests')  

# Show plot 
plt.show()

# %%
# Creating bar chart
plt.bar(guests_mean['guests'], guests_mean['avg_stars'])
plt.title('Rating v Guests')  

# Show plot 
plt.show()

# %%
pricedrop = results[results['previous_price'].notna()]
pricedrop.head()
# Out:
#                                                  name  \
# 1        Brand-New Condo, 2 Blocks to Centennial Park
# 4          1 BR Apartment!! Just 2 miles to Downtown!
# 5   ✧Private Suite & entrance✧2 mi➝DT+coffee+comfy...
# 9        West End Getaway free parking & amazing pool
# 10             Greystone Cottage Basement (CDC Clean)
#
#                            category  superhost  \
# 1     Entire apartment in Nashville        NaN
# 4     Entire apartment in Nashville        NaN
# 5   Entire guest suite in Nashville  SUPERHOST
# 9     Entire apartment in Nashville        NaN
# 10    Entire apartment in Nashville  SUPERHOST
#
#                                                   url  avg_stars  \
# 1   /rooms/35440277?check_in=2020-12-17&check_out=...       4.64
# 4   /rooms/44064578?check_in=2020-12-17&check_out=...       4.00
# 5   /rooms/26764632?check_in=2020-12-17&check_out=...       4.92
# 9   /rooms/43759121?check_in=2020-12-17&check_out=...       4.43
# 10  /rooms/27397940?check_in=2020-12-17&check_out=...       4.94
#
#     review_count  guests beds    bedroom    bath     checkin    checkout  \
# 1           14.0       4    2  1 bedroom  1 bath  2020-12-17  2020-12-20
# 4           10.0       4    1  1 bedroom  1 bath  2020-12-17  2020-12-20
# 5          170.0       3    1  1 bedroom  1 bath  2020-12-17  2020-12-20
# 9           23.0       4    2     Studio  1 bath  2020-12-17  2020-12-20
# 10         127.0       2    1     Studio  1 bath  2020-12-17  2020-12-20
#
#    previous_price discounted not_discounted  current_nightly  total cost  \
# 1             122         58            NaN               58         329
# 4              87         62            NaN               62         257
# 5              77         65            NaN               65         262
# 9             106         84            NaN               84         355
# 10             86         73            NaN               73         318
#
#     room_fee  taxes_fees_cleaning
# 1        174                  155
# 4        186                   71
# 5        195                   67
# 9        252                  103
# 10       219                   99

# %%
pricedrop['previous_price'] = pricedrop['previous_price'].astype(int)
pricedrop['discounted'] = pricedrop['discounted'].astype(int)
# Out:
# <ipython-input-109-38562b52b67e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pricedrop['previous_price'] = pricedrop['previous_price'].astype(int)
# <ipython-input-109-38562b52b67e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pricedrop['discounted'] = pricedrop['discounted'].astype(int)

# %%
pricedrop['price_reduc'] = pricedrop['previous_price'] - pricedrop['discounted']
pricedrop.head()
# Out:
# <ipython-input-110-2b1eb27a03d9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pricedrop['price_reduc'] = pricedrop['previous_price'] - pricedrop['discounted']
#                                                  name  \
# 1        Brand-New Condo, 2 Blocks to Centennial Park
# 4          1 BR Apartment!! Just 2 miles to Downtown!
# 5   ✧Private Suite & entrance✧2 mi➝DT+coffee+comfy...
# 9        West End Getaway free parking & amazing pool
# 10             Greystone Cottage Basement (CDC Clean)
#
#                            category  superhost  \
# 1     Entire apartment in Nashville        NaN
# 4     Entire apartment in Nashville        NaN
# 5   Entire guest suite in Nashville  SUPERHOST
# 9     Entire apartment in Nashville        NaN
# 10    Entire apartment in Nashville  SUPERHOST
#
#                                                   url  avg_stars  \
# 1   /rooms/35440277?check_in=2020-12-17&check_out=...       4.64
# 4   /rooms/44064578?check_in=2020-12-17&check_out=...       4.00
# 5   /rooms/26764632?check_in=2020-12-17&check_out=...       4.92
# 9   /rooms/43759121?check_in=2020-12-17&check_out=...       4.43
# 10  /rooms/27397940?check_in=2020-12-17&check_out=...       4.94
#
#     review_count  guests beds    bedroom    bath     checkin    checkout  \
# 1           14.0       4    2  1 bedroom  1 bath  2020-12-17  2020-12-20
# 4           10.0       4    1  1 bedroom  1 bath  2020-12-17  2020-12-20
# 5          170.0       3    1  1 bedroom  1 bath  2020-12-17  2020-12-20
# 9           23.0       4    2     Studio  1 bath  2020-12-17  2020-12-20
# 10         127.0       2    1     Studio  1 bath  2020-12-17  2020-12-20
#
#     previous_price  discounted not_discounted  current_nightly  total cost  \
# 1              122          58            NaN               58         329
# 4               87          62            NaN               62         257
# 5               77          65            NaN               65         262
# 9              106          84            NaN               84         355
# 10              86          73            NaN               73         318
#
#     room_fee  taxes_fees_cleaning  price_reduc
# 1        174                  155           64
# 4        186                   71           25
# 5        195                   67           12
# 9        252                  103           22
# 10       219                   99           13

# %%
pricedrop['perc_reduc'] = pricedrop['price_reduc'] / pricedrop['previous_price']
pricedrop.head()
# Out:
# <ipython-input-111-90c436c49f24>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pricedrop['perc_reduc'] = pricedrop['price_reduc'] / pricedrop['previous_price']
#                                                  name  \
# 1        Brand-New Condo, 2 Blocks to Centennial Park
# 4          1 BR Apartment!! Just 2 miles to Downtown!
# 5   ✧Private Suite & entrance✧2 mi➝DT+coffee+comfy...
# 9        West End Getaway free parking & amazing pool
# 10             Greystone Cottage Basement (CDC Clean)
#
#                            category  superhost  \
# 1     Entire apartment in Nashville        NaN
# 4     Entire apartment in Nashville        NaN
# 5   Entire guest suite in Nashville  SUPERHOST
# 9     Entire apartment in Nashville        NaN
# 10    Entire apartment in Nashville  SUPERHOST
#
#                                                   url  avg_stars  \
# 1   /rooms/35440277?check_in=2020-12-17&check_out=...       4.64
# 4   /rooms/44064578?check_in=2020-12-17&check_out=...       4.00
# 5   /rooms/26764632?check_in=2020-12-17&check_out=...       4.92
# 9   /rooms/43759121?check_in=2020-12-17&check_out=...       4.43
# 10  /rooms/27397940?check_in=2020-12-17&check_out=...       4.94
#
#     review_count  guests beds    bedroom    bath  ...    checkout  \
# 1           14.0       4    2  1 bedroom  1 bath  ...  2020-12-20
# 4           10.0       4    1  1 bedroom  1 bath  ...  2020-12-20
# 5          170.0       3    1  1 bedroom  1 bath  ...  2020-12-20
# 9           23.0       4    2     Studio  1 bath  ...  2020-12-20
# 10         127.0       2    1     Studio  1 bath  ...  2020-12-20
#
#    previous_price  discounted  not_discounted current_nightly  total cost  \
# 1             122          58             NaN              58         329
# 4              87          62             NaN              62         257
# 5              77          65             NaN              65         262
# 9             106          84             NaN              84         355
# 10             86          73             NaN              73         318
#
#     room_fee  taxes_fees_cleaning  price_reduc  perc_reduc
# 1        174                  155           64    0.524590
# 4        186                   71           25    0.287356
# 5        195                   67           12    0.155844
# 9        252                  103           22    0.207547
# 10       219                   99           13    0.151163
#
# [5 rows x 21 columns]

# %%
# Creating bar chart
plt.bar(pricedrop['guests'], pricedrop['perc_reduc'])
plt.title('Price Drop v Guests')  

# Show plot 
plt.show()

# %%
plt.style.use('seaborn-whitegrid')
x = pricedrop['total cost']
y = pricedrop['perc_reduc']

plt.xlabel('Total Cost')
plt.ylabel('perc_reduc')

plt.plot(x, y, 'o', color='blue', alpha=0.1);

# %%
plt.style.use('seaborn-whitegrid')
x = pricedrop['total cost']
y = pricedrop['taxes_fees_cleaning']

plt.xlabel('Total Cost')
plt.ylabel('perc_reduc')

plt.plot(x, y, 'o', color='blue', alpha=0.1);

# %%
plt.style.use('seaborn-whitegrid')
x = pricedrop['guests']
y = pricedrop['taxes_fees_cleaning']

plt.xlabel('Total Cost')
plt.ylabel('perc_reduc')

plt.plot(x, y, 'o', color='blue', alpha=0.1);

# %%
fig1, ax1 = plt.subplots()
ax1.set_title('Price Reduction (%)')
ax1.boxplot(pricedrop['perc_reduc']);

# %%
ten_guests = results[results['guests']==10]
data = ten_guests['taxes_fees_cleaning']

fig1, ax1 = plt.subplots()
ax1.set_title('Taxes and Fees')
ax1.boxplot(data);
